# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("total_data.csv",low_memory=False)

# %%
df.dtypes
# Out:
# adv_date           object
# area                int64
# build_year          int64
# description        object
# facilities         object
# floor             float64
# link               object
# neighbour_hood     object
# rooms               int64
# Fountain           object
# Central_vaccum    float64
# Sauna               int64
# Security          float64
# Party_room          int64
# Warehouse           int64
# Hot_tubb          float64
# Janitor             int64
# Pool              float64
# Lights            float64
# Roof_grnd           int64
# Gazebo            float64
# Fire_detetor      float64
# Parking             int64
# Lobby_man         float64
# Tercce            float64
# Elevator            int64
# Fire_desabler       int64
# Gym               float64
# Lobby               int64
# Guest_parking     float64
# price               int64
# total_price         int64
# dtype: object

# %%
df
# Out:
#          adv_date  area  build_year  \
# 0      2022-12-26   118        1401
# 1      2022-12-26    65        1386
# 2      2022-12-26   160        1401
# 3      2022-12-26    68        1384
# 4      2022-12-26    87        1400
# ...           ...   ...         ...
# 24247         NaN     3        1401
# 24248         NaN     3        1401
# 24249         NaN    21        1401
# 24250         NaN   100        1401
# 24251         NaN    88        1394
#
#                                              description  \
# 0      ⭕فروش فوری آپارتمان فوق لوکس⭕ \r\n⛔فرصت بازدید...
# 1      ✔️ ۶۵ متر یک خوابه\r\n✔️ فول امکانات (پارکینگ ...
# 2      ♦️۱۶۰ متر \r\n♦️بهترین فرعی بلوار دریا \r\n♦️ف...
# 3      ❌️فایل شخصی لطفا همکاران تماس نگیرند ❌️\r\n⚡️پ...
# 4      پیشنهادی بینظیر برای سخت پسندان\r\n\r\nآپارتما...
# ...                                                  ...
# 24247  طبقه ملک: 12,\n,\nخرید اقساطی در بهترین و معتب...
# 24248  طبقه ملک: 12,\n,\nخرید اقساطی در بهترین و معتب...
# ...

# %%
df["Elevator"].apply(lambda x:{"True": 1, "False": 0, "1": 1, "0": 0}[x])
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 24247    1
# 24248    1
# 24249    1
# 24250    1
# 24251    1
# Name: Elevator, Length: 24252, dtype: int64

# %%
for col in df.columns[10:-2]:
    df[col] = df[col].map({"True": 1, "False": 0, "1": 1, "0": 0})

# %%
df
# Out:
#          adv_date  area  build_year  \
# 0      2022-12-26   118        1401
# 1      2022-12-26    65        1386
# 2      2022-12-26   160        1401
# 3      2022-12-26    68        1384
# 4      2022-12-26    87        1400
# ...           ...   ...         ...
# 24247         NaN     3        1401
# 24248         NaN     3        1401
# 24249         NaN    21        1401
# 24250         NaN   100        1401
# 24251         NaN    88        1394
#
#                                              description  \
# 0      ⭕فروش فوری آپارتمان فوق لوکس⭕ \r\n⛔فرصت بازدید...
# 1      ✔️ ۶۵ متر یک خوابه\r\n✔️ فول امکانات (پارکینگ ...
# 2      ♦️۱۶۰ متر \r\n♦️بهترین فرعی بلوار دریا \r\n♦️ف...
# 3      ❌️فایل شخصی لطفا همکاران تماس نگیرند ❌️\r\n⚡️پ...
# 4      پیشنهادی بینظیر برای سخت پسندان\r\n\r\nآپارتما...
# ...                                                  ...
# 24247  طبقه ملک: 12,\n,\nخرید اقساطی در بهترین و معتب...
# 24248  طبقه ملک: 12,\n,\nخرید اقساطی در بهترین و معتب...
# ...
